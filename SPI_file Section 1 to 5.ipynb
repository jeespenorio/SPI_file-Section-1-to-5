# %%
import pandas as pd

#initialize data

data1 = {
    'Make':['ARCTIC CAT'],
    'Model':['All Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['999544'],
    
    'AD LIST ITEM NUMBER':['1121013'],
    
    'Vendor Notes':[' '] # or you can choose pd.NA
}

#For this column = 'Model':['All Model']
#List All Models
list_models = [
    
'Freeride E-TEC 850 137',
'Freeride E-TEC 850 146',
'Freeride S-38 E-TEC 850 154',
'Freeride E-TEC 850 154',
'Freeride E-TEC 850 Turbo 154',
'Freeride E-TEC 850 Turbo 165',
'Freeride E-TEC 850 Turbo 146'
    
]

#Range of Years in Raw Data given

years = list(range(2007,2025))

#Functions/Syntax to Generate the Dataframe/ Tables

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate all DataFrames or Tables created
final_df = pd.concat(dfs, ignore_index = True)
                     
#Display or Print 
final_df
# Out:
#            Make                         Model Vendor Code  \
# 0    ARCTIC CAT        Freeride E-TEC 850 137        NACH
# 1    ARCTIC CAT        Freeride E-TEC 850 146        NACH
# 2    ARCTIC CAT   Freeride S-38 E-TEC 850 154        NACH
# 3    ARCTIC CAT        Freeride E-TEC 850 154        NACH
# 4    ARCTIC CAT  Freeride E-TEC 850 Turbo 154        NACH
# ..          ...                           ...         ...
# 121  ARCTIC CAT   Freeride S-38 E-TEC 850 154        NACH
# 122  ARCTIC CAT        Freeride E-TEC 850 154        NACH
# 123  ARCTIC CAT  Freeride E-TEC 850 Turbo 154        NACH
# 124  ARCTIC CAT  Freeride E-TEC 850 Turbo 165        NACH
# 125  ARCTIC CAT  Freeride E-TEC 850 Turbo 146        NACH
#
#                        Vendor Name     MPN AD LIST ITEM NUMBER Vendor Notes  \
# 0    NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 1    NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 2    NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 3    NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 4    NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# ..                             ...     ...                 ...          ...
# 121  NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 122  NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 123  NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 124  NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 125  NACHMAN INTERNATIONAL CO. LTD  999544             1121013
#
#      Year
# 0    2007
# 1    2007
# 2    2007
# 3    2007
# 4    2007
# ..    ...
# 121  2024
# 122  2024
# 123  2024
# 124  2024
# 125  2024
#
# [126 rows x 8 columns]

# %%
import pandas as pd

#initialize data

data1 = {
    'Make':['ARCTIC CAT'],
    'Model':['All Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['999544'],
    
    'AD LIST ITEM NUMBER':['1121013'],
    
    'Vendor Notes':[' '] # or you can choose pd.NA
}

#For this column = 'Model':['All Model']
#List All Models
list_models = [
    
'Freeride E-TEC 850 137',
'Freeride E-TEC 850 146',
'Freeride S-38 E-TEC 850 154',
'Freeride E-TEC 850 154',
'Freeride E-TEC 850 Turbo 154',
'Freeride E-TEC 850 Turbo 165',
'Freeride E-TEC 850 Turbo 146'
    
]

#Range of Years in Raw Data given

years = list(range(2007,2025))

#Functions/Syntax to Generate the Dataframe/ Tables

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate all DataFrames or Tables created
final_df = pd.concat(dfs, ignore_index = True)
                     
#Display or Print 
final_df.head(20)
# Out:
#           Make                         Model Vendor Code  \
# 0   ARCTIC CAT        Freeride E-TEC 850 137        NACH
# 1   ARCTIC CAT        Freeride E-TEC 850 146        NACH
# 2   ARCTIC CAT   Freeride S-38 E-TEC 850 154        NACH
# 3   ARCTIC CAT        Freeride E-TEC 850 154        NACH
# 4   ARCTIC CAT  Freeride E-TEC 850 Turbo 154        NACH
# 5   ARCTIC CAT  Freeride E-TEC 850 Turbo 165        NACH
# 6   ARCTIC CAT  Freeride E-TEC 850 Turbo 146        NACH
# 7   ARCTIC CAT        Freeride E-TEC 850 137        NACH
# 8   ARCTIC CAT        Freeride E-TEC 850 146        NACH
# 9   ARCTIC CAT   Freeride S-38 E-TEC 850 154        NACH
# 10  ARCTIC CAT        Freeride E-TEC 850 154        NACH
# 11  ARCTIC CAT  Freeride E-TEC 850 Turbo 154        NACH
# 12  ARCTIC CAT  Freeride E-TEC 850 Turbo 165        NACH
# 13  ARCTIC CAT  Freeride E-TEC 850 Turbo 146        NACH
# 14  ARCTIC CAT        Freeride E-TEC 850 137        NACH
# 15  ARCTIC CAT        Freeride E-TEC 850 146        NACH
# 16  ARCTIC CAT   Freeride S-38 E-TEC 850 154        NACH
# 17  ARCTIC CAT        Freeride E-TEC 850 154        NACH
# 18  ARCTIC CAT  Freeride E-TEC 850 Turbo 154        NACH
# 19  ARCTIC CAT  Freeride E-TEC 850 Turbo 165        NACH
#
#                       Vendor Name     MPN AD LIST ITEM NUMBER Vendor Notes  \
# 0   NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 1   NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 2   NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 3   NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 4   NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 5   NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 6   NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 7   NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 8   NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 9   NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 10  NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 11  NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 12  NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 13  NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 14  NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 15  NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 16  NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 17  NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 18  NACHMAN INTERNATIONAL CO. LTD  999544             1121013
# 19  NACHMAN INTERNATIONAL CO. LTD  999544             1121013
#
#     Year
# 0   2007
# 1   2007
# 2   2007
# 3   2007
# 4   2007
# 5   2007
# 6   2007
# 7   2008
# 8   2008
# 9   2008
# 10  2008
# 11  2008
# 12  2008
# 13  2008
# 14  2009
# 15  2009
# 16  2009
# 17  2009
# 18  2009
# 19  2009

# %%
file_path = r"C:\Users\User\Desktop\excel out\output.csv"
final_df.to_csv(file_path, index = False)
